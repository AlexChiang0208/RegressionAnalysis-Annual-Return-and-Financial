# %% [markdown]
# https://github.com/pandas-profiling/pandas-profiling

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
address = '/Users/alex_chiang/Documents/迴歸分析/期末_多元迴歸/整理資料/'
df = pd.read_csv(address + 'reg_XY_new.csv')
df.drop(columns = ['stock_id', 'Time'], inplace = True)
df
# Out:
#       每股盈餘  ROE(A)－稅後  ROE(B)－常續利益  營業毛利率  營業利益率   稅前淨利率   稅後淨利率  業外收支/營收  \
# 0     0.54       1.99         1.84  10.60   6.67   16.47   15.28     9.79
# 1    -0.16      -0.45        -0.48  13.70  -1.48   -4.61   -9.09    -3.12
# 2    -0.18      -0.88        -0.88   3.38  -7.55   -7.89   -8.05    -0.34
# 3    -0.08      -0.74        -0.78   7.49  -1.86   -5.15   -3.90    -3.29
# 4     0.02       0.19        -0.07  14.91   2.65    3.25    2.73     0.60
# ...    ...        ...          ...    ...    ...     ...     ...      ...
# 7351  0.38       1.63         1.63  28.47   8.98    8.90    6.70    -0.08
# 7352  4.56       6.31         6.31  19.54  10.96  134.08  131.34   123.12
# 7353  0.03       0.14         0.14  25.99   6.63    8.81    6.37     2.18
# 7354 -0.22      -1.40        -1.40   2.27  -3.09   -4.82   -4.82    -1.73
# 7355  1.06       3.35         3.35  29.20  22.84   23.87   18.90     1.03
#
#         貝里比率  常續利益率－稅後  ...  總資產週轉次數   自由現金流量(D)  淨營業週期（日）  淨值週轉率（次）  \
# ...

# %%
profile = ProfileReport(df, minimal=True, title = "Data Report")

# %%
profile.to_file(address + "EDA_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
